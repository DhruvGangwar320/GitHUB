# %% [markdown]
# <a href="https://colab.research.google.com/github/DhruvGangwar320/GitHUB/blob/main/GloVe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
if else based chatbot
NLP
Tect processing
Vectorizer
Machine Learning -> Logistic Regression
Save and laof model
Streamlit based web app

Word Embeddings
- Word2Vec
- GloVe
'''
# Out:
# hello world !

# %%
"""
GloVe
- Global Vectors for Word Representation
- Developed by Stanford University
Unlike Word2Vec (only predicts word based on the word text or it predicts context)
GloVe is a : count-based  +  Matrix factorization
It combines :
1. Statistical word co-occurence
2. Matrix factorization
3. Linear ALgebra
Word2Vec embeddings by predicting context
but it uses :
- local context window
- doesn't directly use global corpus statistics

Core Idea behind GloVe
1. It builds word-word co-occurence matrix

"""
# Out:
# "\nGloVe\n- Global Vectors for Word Representation\n- Developed by Stanford University\nUnlike Word2Vec (only predicts word based on the word text or it predicts context) \nGloVe is a : count-based  +  Matrix factorization\nIt combines : \n1. Statistical word co-occurence\n2. Matrix factorization\n3. Linear ALgebra\nWord2Vec embeddings by predicting context\nbut it uses :\n- local context window\n- doesn't directly use global corpus statistics\n\nCore Idea behind GloVe\n1. It builds word-word co-occurence matrix\n\n"

# %% [markdown]
# # NLP - Visualising Embeddings

# %%
#2. Opposite words separate
#How about we reduce the dimensions

"""
We will use dimensionality reduction :
-Reducing the number of features while preserving important information .
Curse of dimensionality :
We convert :
1000 -> 100
100 -> 10

To solve the curse of Dimensionality

Types of Dimensionality Reduction :
1. Feature Selection  : Remove some less features
2. Feature Extraction : Create new features from the existing features

PCA - Combine features
- finds the direction where data caries most
- these directions = Principal directions
Instead of Original features = we use these directions

Suppose user:
  height and weight are correlated
  Instead of 2 features - PCA creates 1 new feature representing both
Conceptually How PCA works :
1. Standardisation data
2. Compute covariance matrix
3. Find eigenVectors
4. Select Top Components
5. Project Data

Suppose we want 2 components :
PC1 -> most information - (65%)
PC2 -> second most - (20%)
15% loss of data

Limitation of PCA:
1. Linear only
2. Cannot capture comples shapes

T-SNE - t-distributed Stochastic Neighbour Embedding
It preserve :
Local Structure (neighbours)
Points close in high - dim -> close in low-dim
It converst distance into probability
Use KL Divergence formula probability through distance

Use U-MAP - Uniform Manifold Approximation and Projection



"""
# Out:
# '\nWe will use dimensionality reduction : \n-Reducing the number of features while preserving important information .\nCurse of dimensionality : \nWe convert : \n1000 -> 100\n100 -> 10\n\nTo solve the curse of Dimensionality\n\nTypes of Dimensionality Reduction :\n1. Feature Selection  : Remove some less features\n2. Feature Extraction : Create new features from the existing features\n\nPCA - Combine features\n- finds the direction where data caries most\n- these directions = Principal directions\nInstead of Original features = we use these directions\n\nSuppose user:\n  height and weight are correlated\n  Instead of 2 features - PCA creates 1 new feature representing both\nConceptually How PCA works :\n1. Standardisation data\n2. Compute covariance matrix\n3. Find eigenVectors\n4. Select Top Components\n5. Project Data\n\nSuppose we want 2 components : \nPC1 -> most information - (65%)\nPC2 -> second most - (20%)\n15% loss of data\n\nLimitation of PCA:\n1. Linear only\n2. Cannot cap
# ...

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 52.6 MB/s eta 0:00:00
# ...

# %%
import gensim.downloader as api
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
model = api.load("glove-wiki-gigaword-100")
print("Load...")
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded
# Load...

# %%
words = ["king",'queen','lion','man','woman','cat','dog','happy','sad','joy','anger','truck','toy']

# %%
vectors = [ model[word] for word in words]
print(vectors[:10])
# Out:
# [array([-0.32307 , -0.87616 ,  0.21977 ,  0.25268 ,  0.22976 ,  0.7388  ,
#        -0.37954 , -0.35307 , -0.84369 , -1.1113  , -0.30266 ,  0.33178 ,
#        -0.25113 ,  0.30448 , -0.077491, -0.89815 ,  0.092496, -1.1407  ,
#        -0.58324 ,  0.66869 , -0.23122 , -0.95855 ,  0.28262 , -0.078848,
#         0.75315 ,  0.26584 ,  0.3422  , -0.33949 ,  0.95608 ,  0.065641,
#         0.45747 ,  0.39835 ,  0.57965 ,  0.39267 , -0.21851 ,  0.58795 ,
#        -0.55999 ,  0.63368 , -0.043983, -0.68731 , -0.37841 ,  0.38026 ,
#         0.61641 , -0.88269 , -0.12346 , -0.37928 , -0.38318 ,  0.23868 ,
#         0.6685  , -0.43321 , -0.11065 ,  0.081723,  1.1569  ,  0.78958 ,
#        -0.21223 , -2.3211  , -0.67806 ,  0.44561 ,  0.65707 ,  0.1045  ,
#         0.46217 ,  0.19912 ,  0.25802 ,  0.057194,  0.53443 , -0.43133 ,
#        -0.34311 ,  0.59789 , -0.58417 ,  0.068995,  0.23944 , -0.85181 ,
#         0.30379 , -0.34177 , -0.25746 , -0.031101, -0.16285 ,  0.45169 ,
# ...

# %%
pca = PCA(n_components=2)
reduced = pca.fit_transform(vectors)
print(reduced)
# Out:
# [[-4.77026433e-01  3.78257151e+00]
#  [-5.98530506e-02  3.80836684e+00]
#  [ 2.38402621e+00  1.48334393e+00]
#  [ 1.69260130e-03 -1.53307925e-01]
#  [ 1.05554116e-01 -1.14054906e-01]
#  [ 2.61224325e+00 -1.85852890e-01]
#  [ 2.65537170e+00 -8.74791625e-01]
#  [-1.68891590e+00 -4.73727640e-01]
#  [-3.04411899e+00 -1.07936772e+00]
#  [-2.40175199e+00 -7.35445370e-02]
#  [-2.91240687e+00 -1.11637274e+00]
#  [ 6.47201564e-01 -3.07028218e+00]
#  [ 2.17798380e+00 -1.93298012e+00]]

# %%
reduced.shape
# Out:
# (13, 2)

# %%
plt.figure(figsize=(10,6))

for i , word in enumerate(words):
  x = reduced[i][0]
  y = reduced[i][1]
  plt.scatter(x,y)
  plt.text(x,y,word)
plt.show()

# %%
from sklearn.manifold import TSNE
import numpy as np

# %%
vectors = np.array([model[word] for word in words])

# %%
tsne = TSNE(n_components=2 , perplexity = 2)
reduced = tsne.fit_transform(vectors)

# %%
plt.figure(figsize=(10,6))

for i , word in enumerate(words):
  x = reduced[i][0]
  y = reduced[i][1]
  plt.scatter(x,y)
  plt.text(x,y,word)
plt.show()
