# %% [markdown]
# <a href="https://colab.research.google.com/github/DhruvGangwar320/GitHUB/blob/main/DA_Practical_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
marks = np.array([1,2,3,4])
print(marks)
# Out:
# [1 2 3 4]

# %%
data = np.array([
    [1,2,3,4],
    [5,6,7,8],
    [12,23,34,45]
    ])
print(data)
# Out:
# [[ 1  2  3  4]
#  [ 5  6  7  8]
#  [12 23 34 45]]

# %%
# find marks mean
print(marks.mean())
#find marks median
print(np.median(marks))
# Out:
# 2.5
# 2.5

# %%
# if no x -axis then 0 otherwise 1
print(np.mean(data,axis=0))
print(np.mean(data,axis=1))
print(data[0])
# Out:
# [ 6.         10.33333333 14.66666667 19.        ]
# [ 2.5  6.5 28.5]
# [1 2 3 4]

# %%
# data collection - > store in data frame -> preprocess of data (cleaning[deletion of rows and columns])
# if there are lot of null values in a column , then we will find found the corelation of that column with another column

# %%
print(data[2,:])
#print(data[row indexing , column indexing])
# Out:
# [12 23 34 45]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataSet.csv')
df
# Out:
#         Name  Marks  Attendence
# 0      Dhruv   90.0          90
# 1       amit   91.0          91
# 2  Abhimanyu   92.0          92
# 3      Akash    NaN          93
# 4      karan   94.0          94
# 5      pooja   95.0          95
# 6       amit   96.0          96

# %%
# handling missing values
df['Marks'] = df['Marks'].fillna(df['Marks'].mean())
df
# Out:
#         Name  Marks  Attendence
# 0      Dhruv   90.0          90
# 1       amit   91.0          91
# 2  Abhimanyu   92.0          92
# 3      Akash   93.0          93
# 4      karan   94.0          94
# 5      pooja   95.0          95
# 6       amit   96.0          96

# %%
#drop duplicates
df = df.drop_duplicates()
print(df)
# Out:
#         Name  Marks  Attendence
# 0      Dhruv     90          90
# 1       amit     91          91
# 2  Abhimanyu     92          92
# 3      Akash     93          93
# 4      karan     94          94
# 5      pooja     95          95
# 6       amit     96          96

# %%
df['Marks'] = df['Marks'].astype(int)
df['Attendence'] = df['Attendence'].astype(int)

# %%
print("/-Cleaned Data :")
df
# Out:
# /-Cleaned Data :
#         Name  Marks  Attendence
# 0      Dhruv     90          90
# 1       amit     91          91
# 2  Abhimanyu     92          92
# 3      Akash     93          93
# 4      karan     94          94
# 5      pooja     95          95
# 6       amit     96          96

# %% [markdown]
# **Cleaning of Data is done**

# %% [markdown]
# data = np.array([1,2,3,4])

# %%
# correlation of Marks and Attendence
corr = df['Marks'].corr(df['Attendence'])
print('Correlation between Marks and Attendence : ',corr)
# Out:
# Correlation between Marks and Attendence :  1.0

# %%
mean = df['Marks'].mean()
print(mean)
# Out:
# 93.0

# %%
# visualization : ->  pandas
plt.bar(df['Name'],df['Marks'])
plt.title('Marks of Students')
plt.xlabel('Name')
plt.ylabel('Marks')
plt.show()

# %%
# visualization : with :   pandas
plt.scatter(df['Name'],df['Marks'])
plt.title('Marks of Students')
plt.xlabel('Name')
plt.ylabel('Marks')
plt.show()

# %%
# visualization : with :   pandas
plt.plot(df['Name'],df['Marks'] ,marker = 0)
plt.title('Marks of Students')
plt.xlabel('Name')
plt.ylabel('Marks')
plt.show()

# %%
# visualization : with :   pandas
plt.plot(df['Name'],df['Marks'] ,marker = '^')
plt.title('Marks of Students')
plt.xlabel('Name')
plt.ylabel('Marks')
plt.show()

# %%
# For reference, some common markers:
# 'o' - circle marker
# '.' - point marker
# ',' - pixel marker
# 'x' - x marker
# '*' - star marker
# '+' - plus marker
# 's' - square marker
# 'D' - diamond marker
# '^' - triangle_up marker

# %% [markdown]
# Daily expenses data analyses . Create data : data , Food ,Travel charges , Entertainment , import data : perform

# %%
# Out:
#   File "/tmp/ipython-input-457807849.py", line 2
#     plt.scatter(df['Name'],df['Marks'] marker = 0)
#                            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
